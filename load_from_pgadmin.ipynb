# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import boto3
from sqlalchemy import create_engine
from io import StringIO
from config import aws_id, aws_secret, sql_pwd
import psycopg2
from sqlalchemy import create_engine, select

# %%
# Create Database Engine and Load Dataset into Database
connection_string = f"postgres://postgres:{sql_pwd}@group-c-project-db.csna2pebfhlh.us-east-2.rds.amazonaws.com:5432/postgres"

# %%
conn=psycopg2.connect(connection_string)

# %%
cursor = conn.cursor()

# %%
cursor.execute('SELECT * FROM Movie_Data')
rows=cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# <ipython-input-7-f4f79a804719> in <module>
# ----> 1 cursor.execute('SELECT * FROM Movie_Data')
#       2 rows=cursor.fetchall()
#
# InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block

# %%
DF = pd.DataFrame(rows)
DF.head()
# Out:
#                      0    1    2    3    4                     5   \
# 0             Inception  1.0  0.0  0.0  0.0             Inception
# 1            The Matrix  1.0  0.0  0.0  0.0            The Matrix
# 2           The Pianist  1.0  0.0  1.0  0.0           The Pianist
# 3      Django Unchained  1.0  0.0  0.0  0.0      Django Unchained
# 4  Inglourious Basterds  1.0  0.0  0.0  0.0  Inglourious Basterds
#
#             6                   7       8      9   ...     14       15  \
# 0  160000000.0        Warner Bros.     USA  Other  ...  Other  1643094
# 1   63000000.0        Warner Bros.     USA  Other  ...  Other  1348727
# 2   35000000.0               Other  France  Other  ...  Other   560313
# 3  100000000.0               Other     USA  Other  ...  Other  1080790
# 4   75000000.0  Universal Pictures     USA  Other  ...  Other   995116
#
#                   16  17          18         19     20    21  22   23
# 0              Other  en  167.583710  825532764  148.0  2010   7  2.0
# 1              Other  en  104.309993  463517383  136.0  1999   3  2.0
# 2              Other  en   50.587541  120072577  150.0  2003   3  2.0
# 3  Quentin Tarantino  en   82.121691  425368238  165.0  2012  12  2.0
# 4  Quentin Tarantino  en   72.595961  319131050  153.0  2009   8  2.0
#
# [5 rows x 24 columns]

# %%
movies_df = pd.read_sql(sql="Movie_Data_Pre-Encoding", con=engine)
